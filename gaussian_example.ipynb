# %%
import matplotlib.pyplot as plt
from distgen import Generator

# create beam
gen = Generator("beams/gaussian.yaml")
gen.run()
gen
# Out:
# <disgten.Generator with input:
# n_particle: 1000
# output:
#   file: rad.gaussian.out.txt
#   type: gpt
# px_dist:
#   sigma_px:
#     units: MeV/c
#     value: 0.001
#   type: gaussian
# py_dist:
#   sigma_py:
#     units: MeV/c
#     value: 0.001
#   type: gaussian
# pz_dist:
#   avg_pz:
#     units: MeV/c
#     value: 1.0
#   sigma_pz:
#     units: MeV/c
#     value: 1.0e-05
#   type: gaussian
# r_dist:
#   sigma_xy:
#     units: mm
#     value: 10
#   type: radial_gaussian
# random_type: hammersley
# start:
#   tstart:
#     units: sec
#     value: 0
#   type: time
# t_dist:
#   max_t:
#     units: ps
#     value: 2
#   min_t:
#     units: ps
#     value: -2
#   type: uniform
# total_charge:
#   units: pC
#   value: 10
#
# >

# %%
particles = gen.particles

particles.plot("x","xp")
particles.plot("z","pz")

# %%
particles
# Out:
# <ParticleGroup with 1000 particles at 0x1e0d38baf50>

# %%
# transform particles from distgen to BMAD
from track import Particle
import torch

keys = ["x","px","y","py","z","pz"]
defaults = {
        "s": torch.tensor(0.0),
        "p0c": torch.mean(torch.tensor(particles.pz)),
        "mc2": torch.tensor(particles.mass),
    }
print(defaults["p0c"])

ground_truth_in = Particle(
    torch.tensor(particles.x),
    torch.tensor(particles.xp),
    torch.tensor(particles.y),
    torch.tensor(particles.yp),
    torch.tensor(particles.z),
    (torch.tensor(particles.pz) - defaults["p0c"]) / defaults["p0c"],
    **defaults
)
# Out:
# tensor(1000000., dtype=torch.float64)

# %%
from normalizing_flow import get_images, image_difference_loss, get_output_beams

# get ground truth images
sizes = []
k_in = torch.linspace(-10,10,5)
bins = torch.linspace(-50,50,100)*1e-3
bandwidth = torch.tensor(1e-3)
ground_truth_output_beams = get_output_beams(ground_truth_in, k_in)
images = get_images(ground_truth_output_beams, bins, bandwidth)

for image in images[:5]:
    fig,ax = plt.subplots()
    xx = torch.meshgrid(bins, bins)
    ax.pcolor(xx[0], xx[1], image)

# test loss
image_difference_loss(ground_truth_in, ground_truth_in, k_in, bins, bandwidth)
# Out:
# tensor(0., dtype=torch.float64)

# %%
# define a unit multivariate normal
from torch.distributions import MultivariateNormal
normal_samples = MultivariateNormal(torch.zeros(6), torch.eye(6)).sample([1000])

# define nonparametric transform
from normalizing_flow import NonparametricTransform, track_in_quad
tnf = NonparametricTransform()

# plot initial beam after transform
p_in_guess = Particle(*tnf(normal_samples).T.double(), **defaults)
plt.hist2d(p_in_guess.x.detach().numpy(), p_in_guess.px.detach().numpy(), bins=50)

plt.figure()
p_out_guess = track_in_quad(p_in_guess, k_in[0])
plt.hist2d(p_out_guess.x.detach().numpy(), p_out_guess.px.detach().numpy(), bins=50);

# %%
# preform optimization with Adam to generate a beam with zero centroid
from normalizing_flow import image_difference_loss, beam_position_loss, zero_centroid_loss

optim = torch.optim.Adam(tnf.parameters(), lr=0.001, weight_decay=1e-5)
n_iter = 1000
losses = []
image_difference_losses = []
beam_position_losses = []

keys = ["x", "px", "y", "py", "z", "pz"]

for i in range(n_iter):
    optim.zero_grad()

    #transformed_samples = tnf(normal_samples).double()
    guess_dist = Particle(*tnf(normal_samples).T.double(), **defaults)
    #coords = torch.cat([getattr(guess_dist, key).unsqueeze(0) for key in keys], dim=0)
    #loss = torch.sum(coords.mean(dim=0).pow(2)).sqrt()

    loss = image_difference_loss(
        guess_dist,
        ground_truth_in,
        k_in,
        bins=bins,
        bandwidth=bandwidth
    )
    losses += [loss.detach()]
    loss.backward()

    optim.step()

    if i % 100 == 0:
        print(i)

fig, ax = plt.subplots()
ax.semilogy(losses)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [35], in <cell line: 12>()
#      16 guess_dist = Particle(*tnf(normal_samples).T.double(), **defaults)
#      17 #coords = torch.cat([getattr(guess_dist, key).unsqueeze(0) for key in keys], dim=0)
#      18 #loss = torch.sum(coords.mean(dim=0).pow(2)).sqrt()
# ---> 20 loss = image_difference_loss(
#      21     guess_dist,
#      22     ground_truth_in,
#      23     k_in,
#      24     bins=bins,
#      25     bandwidth=bandwidth
#      26 )
#      27 losses += [loss.detach()]
#      28 loss.backward()
#
# File ~\Documents\GitHub\phase_space_reconstruction\normalizing_flow.py:63, in image_difference_loss(test_beam, true_beam, k_in, bins, bandwidth, plot_images)
#      60 def image_difference_loss(test_beam, true_beam, k_in, bins, bandwidth,
#      61                           plot_images=False):
#      62     test_output_beams = get_output_beams(test_beam, k_in)
# ---> 63     true_output_beams = get_output_beams(true_beam, k_in)
#      65     # calculate total centroid deviation at the start and end of the beamline
#      67     beam1_images = get_images(test_output_beams, bins, bandwidth)
#
# File ~\Documents\GitHub\phase_space_reconstruction\normalizing_flow.py:30, in get_output_beams(beam, k_in)
#      28 output_beams = []
#      29 for ele in k_in:
# ---> 30     output_beams.append(track_in_quad(beam, ele))
#      31 return output_beams
#
# File ~\Documents\GitHub\phase_space_reconstruction\normalizing_flow.py:14, in track_in_quad(beam, k)
#      11 drift = Drift(L=torch.tensor(1.0))
#      12 lattice = [quad, drift]
# ---> 14 return track_a_lattice(beam, lattice)[-1]
#
# File ~\Documents\GitHub\phase_space_reconstruction\track.py:255, in track_a_lattice(p_in, lattice)
#     253     ele = lattice[i]
#     254     track_f = tracking_function_dict[type(ele).__name__]
# --> 255     all_p[i + 1] = track_f(all_p[i], ele)
#     257 return all_p
#
# File ~\Documents\GitHub\phase_space_reconstruction\track.py:39, in make_track_a_drift.<locals>.track_a_drift(p_in, drift)
#      36 Py = py / P  # Particle's 'y' momentum over p0
#      37 Pxy2 = Px ** 2 + Py ** 2  # Particle's transverse mometum^2 over p0^2
# ---> 39 if any(Pxy2 > 1.0):
#      40     raise RuntimeError("Erronious particle")
#      42 Pl = sqrt(1 - Pxy2)  # Particle's longitudinal momentum over p0
#
# KeyboardInterrupt:

# %%
loss = image_difference_loss(
        Particle(*tnf(normal_samples).T.double(), **defaults),
        ground_truth_in,
        k_in,
        bins=bins,
        bandwidth=bandwidth,
        plot_images=True
    )

# %%
# plot initial beam after transform
p_in_guess = Particle(*tnf(normal_samples).T.double(), **defaults)
plt.hist2d(p_in_guess.x.detach().numpy(), p_in_guess.px.detach().numpy(), bins=50)

plt.figure()
p_out_guess = track_in_quad(p_in_guess, k_in[0])
plt.hist2d(p_out_guess.x.detach().numpy(), p_out_guess.y.detach().numpy(), bins=50);
