# %% [markdown]
# # PS reconstruction, non-Gaussian beam, t scan study

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt

from phase_space_reconstruction.virtual.beamlines import quadlet_tdc_bend
from phase_space_reconstruction.virtual.scans import run_3d_scan, run_t_scan
from phase_space_reconstruction.diagnostics import ImageDiagnostic
from phase_space_reconstruction.visualization import plot_3d_scan_data
from phase_space_reconstruction.train import train_3d_scan, train_3d_scan_parallel_gpus

from bmadx.distgen_utils import create_beam
from bmadx.plot import plot_projections
from bmadx.constants import PI

# %% [markdown]
# ## Create synthetic ground truth beam

# %%
# create synthetic ground truth beam from base and transform yaml files
yaml_dir = os.path.join('data', 'yaml_files')
save_dir = os.path.join('data', 'non_gaussian_beam', 'no-E-corr')
p0c = 43.36e6 # reference momentum in eV/c
gt_beam = create_beam(
    base_yaml = os.path.join(yaml_dir, 'base.yaml'),
    transforms_yaml = os.path.join(yaml_dir, 'transforms-nonlinear-no-E-corr.yaml'), 
    p0c = p0c,
    n_particle = 100_000,
    save_as = os.path.join(save_dir, 'non_gaussian_beam.pt')
)

data = gt_beam.data.clone()
gt_beam.data = data * 0.5
# Out:
# ground truth distribution saved at data/non_gaussian_beam/no-E-corr/non_gaussian_beam.pt

# %%
#plot gt beam
lims = np.array([[-7e-3, 7e-3],
                 [-7e-3, 7e-3],
                 [-7e-3, 7e-3],
                 [-7e-3, 7e-3],
                 [-7e-3, 7e-3],
                 [-5e-2, 5e-2]]) 
fig, ax = plot_projections(
    gt_beam.numpy_particles(),
    custom_lims = lims,
    background = 0
)
plt.show()

# %% [markdown]
# ## Define diagnostics lattice parameters

# %%
# triplet params obtained from triplet-opt.ipynb
k1 =     8.75034
k2 =  -24.402993
k3 =   25.628154

# k1 =     6.10308
# k2 =  -24.441689
# k3 =   25.971829

# %%
# diagnostic beamline:
lattice = quadlet_tdc_bend(p0c=p0c, dipole_on=False)
lattice.elements[0].K1.data = torch.tensor(k1)
lattice.elements[2].K1.data = torch.tensor(k2)
lattice.elements[4].K1.data = torch.tensor(k3)

# Scan over quad strength, tdc on/off and dipole on/off
scan_ids = [6, 8, 10] 
n_ks = 5
ks = torch.linspace(-10, 10, n_ks) # quad ks
vs = torch.tensor([0, 5e6]) # TDC off/on
gs = torch.tensor([2.22e-16, 20.0*PI/180.0/0.365]) # dipole off/on
train_params = torch.stack(torch.meshgrid(ks, vs, gs, indexing='ij'))
print(train_params.shape)
print(train_params.unsqueeze(-1).shape)

# create diagnostic screen: 
bins = torch.linspace(-25, 25, 200) * 1e-3
bandwidth = (bins[1]-bins[0]) / 2
screen = ImageDiagnostic(bins, bins, bandwidth)
# Out:
# torch.Size([3, 5, 2, 2])
# torch.Size([3, 5, 2, 2, 1])

# %% [markdown]
# ## 'T' scan training data

# %%
# generate and save train and test datasets
train_dset_t_scan = run_t_scan(
    gt_beam, 
    lattice,
    screen, 
    ks, vs, gs,
    ids = scan_ids,
    save_as = os.path.join(save_dir, 't_scan.dset')
    )

print(train_dset_t_scan.params.shape)
print(train_dset_t_scan.images.shape)
# Out:
# torch.Size([8, 3, 1])
# tensor([[-1.0000e+01,  0.0000e+00,  2.2200e-16],
#         [-5.0000e+00,  0.0000e+00,  2.2200e-16],
#         [ 0.0000e+00,  0.0000e+00,  2.2200e-16],
#         [ 5.0000e+00,  0.0000e+00,  2.2200e-16],
#         [ 1.0000e+01,  0.0000e+00,  2.2200e-16],
#         [ 0.0000e+00,  0.0000e+00,  9.5634e-01],
#         [ 0.0000e+00,  5.0000e+06,  2.2200e-16],
#         [ 0.0000e+00,  5.0000e+06,  9.5634e-01]])
# dataset saved as 'data/non_gaussian_beam/no-E-corr/t_scan.dset'
# torch.Size([8, 3, 1])
# torch.Size([8, 1, 200, 200])

# %%
for ele in train_dset_t_scan.images:
    plt.figure()
    plt.imshow(ele.squeeze())

# %%
# %%time

# training
pred_beam_t_scan_100_000, model = train_3d_scan(
    train_dset_t_scan, 
    lattice, 
    p0c, 
    screen,
    ids = scan_ids,
    n_epochs = 6_000, 
    n_particles = 100_000, 
    device = 'cuda:0',
    lambda_=1e14,
    save_dir = save_dir,
    distribution_dump_frequency=500,
    distribution_dump_n_particles=1_000_000,
    )
# Out:
# Using device: cuda:0
# /global/homes/r/rroussel/.conda/envs/ps-reconstruction/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /home/conda/feedstock_root/build_artifacts/pytorch-recipe_1694463969407/work/aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 0 tensor(3.3882e+09, device='cuda:0', grad_fn=<MulBackward0>)
# 100 tensor(4.8433e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 200 tensor(4.3717e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 300 tensor(4.6112e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 400 tensor(3.9054e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 500 tensor(3.8528e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 600 tensor(3.7579e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 700 tensor(3.8584e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 800 tensor(3.8775e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 900 tensor(3.8753e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1000 tensor(4.0653e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1100 tensor(3.7805e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1200 tensor(3.6954e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1300 tensor(3.6698e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1400 tensor(3.5486e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1500 tensor(3.5668e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1600 tensor(3.6279e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1700 tensor(3.9114e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1800 tensor(3.7042e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 1900 tensor(3.7405e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2000 tensor(3.5970e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2100 tensor(3.5613e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2200 tensor(3.7934e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2300 tensor(3.6817e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2400 tensor(3.4053e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2500 tensor(3.7569e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2600 tensor(3.4798e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2700 tensor(3.4433e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2800 tensor(3.5516e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 2900 tensor(3.5309e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3000 tensor(3.4072e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3100 tensor(3.5376e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3200 tensor(3.5470e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3300 tensor(3.4632e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3400 tensor(3.5684e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3500 tensor(3.6535e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3600 tensor(3.4551e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3700 tensor(3.4019e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3800 tensor(3.4069e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 3900 tensor(3.3697e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4000 tensor(3.3981e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4100 tensor(3.4328e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4200 tensor(3.4212e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4300 tensor(3.5923e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4400 tensor(4.0778e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4500 tensor(3.3470e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4600 tensor(3.4427e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4700 tensor(3.5100e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4800 tensor(3.3488e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 4900 tensor(3.6554e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5000 tensor(3.4577e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5100 tensor(3.5034e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5200 tensor(3.3924e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5300 tensor(3.3166e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5400 tensor(3.4638e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5500 tensor(3.4109e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5600 tensor(3.4060e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5700 tensor(3.3239e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5800 tensor(3.3621e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 5900 tensor(3.5129e+08, device='cuda:0', grad_fn=<MulBackward0>)
# 6000 tensor(3.5540e+08, device='cuda:0', grad_fn=<MulBackward0>)
# CPU times: user 14min 35s, sys: 1min 55s, total: 16min 31s
# Wall time: 12min 56s

# %%
# make predictions of the beam phase space
model.beam.set_base_beam(1_000_000, p0c=torch.tensor(p0c))
predicted_beam = model.beam.forward().detach_clone()
model.beam.set_base_beam(1_000, p0c=torch.tensor(p0c))

# %%
# reconstructed beam projections:
fig, ax = plot_projections(
    pred_beam_t_scan_100_000.numpy_particles(),
    custom_lims = lims
)
plt.show()

# %%
torch.cuda.empty_cache()

# %%
torch.save(predicted_beam,
           os.path.join(save_dir, 'pred_beam_t_scan_1_000_000.pt'))

# %%
import torch
from stats import plot_projections_with_contours
import os
plot_projections_with_contours(
    torch.load(os.path.join(save_dir, 'pred_beam_t_scan_1_000_000.pt')),
    gt_beam,
    bins=100,
    contour_percentiles = [50, 95],
    custom_lims=lims,
    contour_smoothing_r=0.5,
    contour_smoothing_gt=0.5,
)
# Out:
# (<Figure size 3600x3600 with 36 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='px (mrad)'>, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >],
#         [<Axes: ylabel='y (mm)'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >],
#         [<Axes: ylabel='py (mrad)'>, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >],
#         [<Axes: ylabel='z (mm)'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >],
#         [<Axes: xlabel='x (mm)', ylabel='pz (mrad)'>,
#          <Axes: xlabel='px (mrad)'>, <Axes: xlabel='y (mm)'>,
#          <Axes: xlabel='py (mrad)'>, <Axes: xlabel='z (mm)'>,
#          <Axes: xlabel='pz (mrad)'>]], dtype=object))

# %%
plot_projections_with_contours(
    torch.load(os.path.join(save_dir, 'dist_1000.pt')),
    gt_beam,
    bins=100,
    contour_percentiles = [50, 95],
    custom_lims=lims,
    contour_smoothing_r=0.5,
    contour_smoothing_gt=0.5,
)
# Out:
# (<Figure size 3600x3600 with 36 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: ylabel='px (mrad)'>, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >],
#         [<Axes: ylabel='y (mm)'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >],
#         [<Axes: ylabel='py (mrad)'>, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >, <Axes: >],
#         [<Axes: ylabel='z (mm)'>, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#          <Axes: >],
#         [<Axes: xlabel='x (mm)', ylabel='pz (mrad)'>,
#          <Axes: xlabel='px (mrad)'>, <Axes: xlabel='y (mm)'>,
#          <Axes: xlabel='py (mrad)'>, <Axes: xlabel='z (mm)'>,
#          <Axes: xlabel='pz (mrad)'>]], dtype=object))
