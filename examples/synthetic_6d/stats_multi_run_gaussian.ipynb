# %%
import os
import time
import torch
import numpy as np
import matplotlib.pyplot as plt

from phase_space_reconstruction.virtual.beamlines import quadlet_tdc_bend
from phase_space_reconstruction.virtual.scans import run_3d_scan, run_t_scan
from phase_space_reconstruction.diagnostics import ImageDiagnostic
from phase_space_reconstruction.visualization import plot_3d_scan_data
from phase_space_reconstruction.train import train_3d_scan

from bmadx.plot import plot_projections
from bmadx.constants import PI

# %% [markdown]
# ## Create synthetic ground truth beam

# %%
# load ground truth beam
gt = torch.load(os.path.join('data','gaussian_beam','stats','gaussian_beam.pt'))

# plot gt beam
lims = np.array([[-15e-3, 15e-3],
                 [-15e-3, 15e-3],
                 [-15e-3, 15e-3],
                 [-15e-3, 15e-3],
                 [-5e-3, 5e-3],
                 [-5e-2, 5e-2]]) 
fig, ax = plot_projections(
    gt.numpy_particles(),
    custom_lims = lims,
    background = 0
)
plt.show()

# %%
# load train dataset
train_dset = torch.load(os.path.join('data','gaussian_beam','stats','3d_scan_train.dset'))
print(train_dset.params.shape)
print(train_dset.images.shape)

# plot training dataset
fig, ax = plot_3d_scan_data(train_dset)
plt.show()
# Out:
# torch.Size([20, 3, 1])
# torch.Size([20, 1, 200, 200])

# %%
# lattice:
# reference momentum in eV/c
p0c = 43.36e6 

# triplet params obtained from triplet-opt.ipynb
k1 = 2.917415
k2 = -20.0
k3 = 15.274649

# diagnostic beamline:
lattice = quadlet_tdc_bend(p0c=p0c, dipole_on=False)
lattice.elements[0].K1.data = torch.tensor(k1)
lattice.elements[2].K1.data = torch.tensor(k2)
lattice.elements[4].K1.data = torch.tensor(k3)

# Scan over quad strength, tdc on/off and dipole on/off
scan_ids = [6, 8, 10] 
n_ks = 5
ks = torch.linspace(-10, 10, n_ks) # quad ks
vs = torch.tensor([0, 1e7]) # TDC off/on
gs = torch.tensor([2.22e-16, 20.0*PI/180.0/0.365]) # dipole off/on
train_params = torch.stack(torch.meshgrid(ks, vs, gs, indexing='ij'))

# create diagnostic screen: 
bins = torch.linspace(-50, 50, 200) * 1e-3
bandwidth = (bins[1]-bins[0]) / 2
screen = ImageDiagnostic(bins, bins, bandwidth)

# %%
def train_single_model(seed):
    fname = f'r_{seed}.pt'
    torch.manual_seed(seed)
    pred_beam = train_3d_scan(
        train_dset, 
        lattice, 
        p0c, 
        screen,
        ids = scan_ids,
        n_epochs = 2_000, 
        n_particles = 100_000, 
        device = torch.device('cuda:1'),
        save_as = os.path.join('data','gaussian_beam','stats_2',fname)
    )
    torch.cuda.empty_cache()
    
def train_sequentially(seed_initial, seed_final):
    for seed in range(seed_initial, seed_final+1):
        print(f'--------------------')
        print(f'---SEED: {seed}--------')
        print(f'--------------------')
        train_single_model(seed)

# %%
seed_initial = 1
seed_final = 10
train_sequentially(seed_initial, seed_final)
# Out:
# --------------------
# ---SEED: 1--------
# --------------------
# Using device: cuda:1
# /global/common/software/m669/jpga/conda/envs/ps-reconstruction/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /home/conda/feedstock_root/build_artifacts/pytorch-recipe_1680572619157/work/aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 0 tensor(3288112.7500, device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(346663.5312, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(334135.5625, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(313447.8125, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(300061.6875, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(290984.8438, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(335720.7500, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(321700.1875, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(318832.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(350676.9062, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(331509.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(342214.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(317629.7188, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(315251.1250, device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(321330.8438, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(352775.6250, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(311754.1562, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(338277.2500, device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(359475.4062, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(352340.5625, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 2--------
# --------------------
# Using device: cuda:1
# 0 tensor(3113357., device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(319646., device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(327602.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(325658.8438, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(406837.5938, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(341011.0938, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(342851.6875, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(315708.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(295541.7188, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(326999.4062, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(353507.9375, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(345243.6875, device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(363588.3750, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(295069.0938, device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(299763.6562, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(318922.4062, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(317893.9375, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(341096.5000, device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(333794.1875, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(347806.6562, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 3--------
# --------------------
# Using device: cuda:1
# 0 tensor(3361915.5000, device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(329307.4062, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(281626., device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(335503.6562, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(352308.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(307411.1250, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(302324.0312, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(342429.1875, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(334378.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(358541.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(313311.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(326761.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(303604.3750, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(289549.5000, device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(306099.9375, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(315709.4375, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(330291.6875, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(327449.1250, device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(323870.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(304681.6562, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 4--------
# --------------------
# Using device: cuda:1
# 0 tensor(3303634.5000, device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(357380.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(340726.5625, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(339199.6875, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(325117.6250, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(320650.1250, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(308826.9062, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(316197.0625, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(323115.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(334928.0625, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(320649.2812, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(317011.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(336586.4375, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(315147.0625, device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(317459.2500, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(339792.0938, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(321263.7188, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(300693., device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(327754.0625, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(320634.6250, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 5--------
# --------------------
# Using device: cuda:1
# 0 tensor(3621313., device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(368934.9062, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(327794.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(306069.9375, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(341006.4375, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(301851.5625, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(335527.9062, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(340012.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(328021.2812, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(306934.0938, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(327986.7188, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(319853., device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(337979.1875, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(326760., device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(286893.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(296000.2812, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(304661.4062, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(308969.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(343792.8125, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(357140.2500, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 6--------
# --------------------
# Using device: cuda:1
# 0 tensor(3016581.7500, device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(369131.1875, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(335344.5938, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(342931.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(331544.1562, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(332122.1562, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(315552.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(322336.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(318943., device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(310505.2812, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(319333.9062, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(311775.5312, device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(330637.6562, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(328919.4062, device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(323262.1875, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(316579.3750, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(315764.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(298878.2500, device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(341891.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(329498.7812, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 7--------
# --------------------
# Using device: cuda:1
# 0 tensor(3293009., device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(331927.4375, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(303884.3750, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(299492., device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(331752.5000, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(330605.8438, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(308772.8438, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(315845.8750, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(323704.8438, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(330030.4062, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(345098.0312, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(301834.9062, device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(304098.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(309369.7188, device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(310834.5938, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(331882.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(370759.4062, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(314786.1875, device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(304160.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(311967.7500, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 8--------
# --------------------
# Using device: cuda:1
# 0 tensor(3389717., device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(385909.7188, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(333422.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(312846.4688, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(335408.3438, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(305191.6875, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(384356.2500, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(298633.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(337157.5625, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(313349.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(325714.5625, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(348894.6875, device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(306609.8438, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(316181.0312, device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(312608.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(320721.7188, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(310088.4375, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(383771.4375, device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(306336.1250, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(330750.6250, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 9--------
# --------------------
# Using device: cuda:1
# 0 tensor(3910789., device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(350818.0312, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(312174.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(296262.5938, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(340113.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(328245.5938, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(328124.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(358057.2812, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(314921.1562, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(300794.3438, device='cuda:1', grad_fn=<MulBackward0>)
# 1000 tensor(319961.3125, device='cuda:1', grad_fn=<MulBackward0>)
# 1100 tensor(370337.5000, device='cuda:1', grad_fn=<MulBackward0>)
# 1200 tensor(305500.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 1300 tensor(304871.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 1400 tensor(332301.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 1500 tensor(317486.6562, device='cuda:1', grad_fn=<MulBackward0>)
# 1600 tensor(311560.0938, device='cuda:1', grad_fn=<MulBackward0>)
# 1700 tensor(307484.2500, device='cuda:1', grad_fn=<MulBackward0>)
# 1800 tensor(300446.2188, device='cuda:1', grad_fn=<MulBackward0>)
# 1900 tensor(295279.9062, device='cuda:1', grad_fn=<MulBackward0>)
# --------------------
# ---SEED: 10--------
# --------------------
# Using device: cuda:1
# 0 tensor(2996684.2500, device='cuda:1', grad_fn=<MulBackward0>)
# 100 tensor(334060.9688, device='cuda:1', grad_fn=<MulBackward0>)
# 200 tensor(325435.7812, device='cuda:1', grad_fn=<MulBackward0>)
# 300 tensor(344267.0938, device='cuda:1', grad_fn=<MulBackward0>)
# 400 tensor(330850.0312, device='cuda:1', grad_fn=<MulBackward0>)
# 500 tensor(327947.8750, device='cuda:1', grad_fn=<MulBackward0>)
# 600 tensor(315034.1875, device='cuda:1', grad_fn=<MulBackward0>)
# 700 tensor(303537.2812, device='cuda:1', grad_fn=<MulBackward0>)
# 800 tensor(364562.2500, device='cuda:1', grad_fn=<MulBackward0>)
# 900 tensor(302357.2500, device='cuda:1', grad_fn=<MulBackward0>)
