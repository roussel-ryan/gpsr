# %%
from generate_test_beam import generate_test_beam, generate_test_images

# %%
#generate_test_beam()

# %%
generate_test_images()
# Out:
# tensor([-25.], device='cuda:0') tensor(195.7752, device='cuda:0', dtype=torch.float64)
# tensor([-18.6842], device='cuda:0') tensor(118.2558, device='cuda:0', dtype=torch.float64)
# tensor([-12.3684], device='cuda:0') tensor(61.1976, device='cuda:0', dtype=torch.float64)
# tensor([-6.0526], device='cuda:0') tensor(23.4242, device='cuda:0', dtype=torch.float64)
# tensor([0.2632], device='cuda:0') tensor(3.8068, device='cuda:0', dtype=torch.float64)
# tensor([6.5789], device='cuda:0') tensor(1.2623, device='cuda:0', dtype=torch.float64)
# tensor([12.8947], device='cuda:0') tensor(14.7515, device='cuda:0', dtype=torch.float64)
# C:\ProgramData\Miniconda3\envs\phase_space_reconstruction\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:2228.)
# ...
