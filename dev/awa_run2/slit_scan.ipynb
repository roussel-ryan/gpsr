# %%
import numpy as np

fpath = "D:\AWA\phase_space_tomography_run2\Slitscan_data\Vertical_50um" \
        "\Reconstructed_particle_dist\\"

y = np.load(fpath + "y_recon.npy")
yp = np.load(fpath + "yp_recon.npy")

# %%
import matplotlib.pyplot as plt
plt.plot(y[::100]*1e3,yp[::100]*1e3,'.',ms=1)
plt.figure()
plt.hist2d(y*1e3,yp*1e3, bins=100);
