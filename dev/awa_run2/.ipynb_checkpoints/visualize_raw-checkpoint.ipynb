# %%
import numpy as np
import matplotlib.pyplot as plt
image_data = np.load("image_data.npy")
quad_strengths = np.load("quad_strength.npy")

offset = 150
image_data = np.clip(image_data, offset, 1e10) - offset

# %%
image_data.shape
# Out:
# (16, 5, 160, 160)

# %%
plt.plot(image_data[0,0].sum(axis=-1))

# %%
plt.imshow(image_data[0,0] > 0)
plt.colorbar()
